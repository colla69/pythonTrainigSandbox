# %%
import eyed3
import os
import mechanicalsoup
import requests
import json

brow = mechanicalsoup.StatefulBrowser()
base = "https://api-v2.soundcloud.com"
offset = "?offset=0&limit=100"
add_info="&client_id=tNdzqSQH10kJuLrRhPLbf5wtQEnaXmi1&app_version=1564667264&app_locale=en"
path = "/media/cola/Transfer/Download/SCscrape/"
dlink = "https://sclouddownloader.com/"
d_cmd = 'wget "{}" -O "{}"'


def mk_dir(_path):
    if not os.path.exists(_path):
        os.mkdir(_path)

    
def print_tag(file):
    try:
        print('loading: '+file)
        audiofile = eyed3.load(file)
    except Exception as e:
        print(e)
    print('tags:')
    try:
        print( "artist: " + audiofile.tag.artist )
    except:
        print("artist: none" )
    try:
        print("title: " + audiofile.tag.title)
    except:
        print("title: none" )
    try:
        audiofile.tag.album = u"PaoloSCLikes"
        print("album: " + audiofile.tag.album)
    except:
        print("album: none" )
    try:
        print("genre: " + audiofile.genre.tag.name)
    except:
        print("genre: none" )
    audiofile.tag.save()        


def download_song(sclink, title, index):
    file_name = path+title+".mp3"
    mess = "downloading: {}".format(file_name)                                    
    if os.path.isfile(file_name):                
        print("SKIP -{}- {}".format(index, mess))
        return count
    brow.open(dlink)
    form = brow.select_form('form')
    form["sound-url"] = sclink 
    brow.submit_selected()            
    dpage = brow.get_current_page()    
    aas = dpage.find_all("a")
    for a in aas:            
        try:
            tmp = a["onclick"]
            tmps = tmp.split("'")
            
            file_name = path+title+".mp3"                
            cmd = d_cmd.format(tmps[1], file_name)
            os.system(cmd)   
            print("DONE -{}- {}".format(index, mess))            
        except Exception as e:            
            # print(e)
            continue
            
            
def download_track(element, count):
    username = element["user"]["username"]            
    try:
        tr = element["track"]
        print("downloading track:")
    except:
        raise ValueError("Not a Track")
        return count
    if username != tr["user"]["username"]:
        print("SKIP - Repost by user")
        return count+1
    title = tr["title"]
    link = tr["permalink_url"]
    download_song(link, title, count)                        
    return count+1
    
            
def download_playlist(element, count):
    username = element["user"]["username"]  
    try:
        playlist = element["playlist"]
    except:
        raise ValueError("Not a playlist")
        print(element)
    if username != playlist["user"]["username"]:
        print("SKIP - Repost by user")
        return count+1
    tracks = playlist["tracks"] 
    for tr in tracks:
        try:
            title = tr["title"]
            link = tr["permalink_url"]
            download_song(link, title, count)
        except:
            pass
    return count+1
          
        
def do_work(req):    
    link = base+req+offset+add_info    
    print("Downloading tracks from {}\n".format(link))
    resp = requests.get(link)
    json_data = json.loads(resp.text)
    collection = json_data["collection"]
    next_ref = json_data["next_href"]
    next_p = next_ref + add_info
    # print(json_data)
    global count
    count = 0 
    while next_ref is not None:        
        next_p = next_ref + add_info

        for el in collection:
            try:
                eltype = el["type"]
                if eltype.lower()=="track":
                    print("downloading track:")
                    count = download_track(el, count)
                elif eltype.lower()=="playlist":
                    print("downloading playlist:")
                    count = download_playlist(el, count)
                else:
                    print(eltype)
            except Exception as e:
                # print(e)
                try:
                    count = download_playlist(el, count)
                    break
                except Exception as e:
                    print(e)
                continue
        
        print("\nDone {} .. Scrolling  to {}\n".format(count, next_p))    
        resp = requests.get(next_p)
        json_data = json.loads(resp.text)
        collection = json_data["collection"]        
        next_ref = json_data["next_href"]            
    print("\nDone {}".format(count))    
    
    
# link to Soundcloud REST API "https://api-v2.soundcloud.com/" 
req = "/stream/users/1250539" # (e.G. 'stream/users/216049')
name = "Billy Talent"
path += name+"/"
mk_dir(path)
do_work(req)
# Out:
# Downloading tracks from https://api-v2.soundcloud.com/stream/users/1250539?offset=0&limit=100&client_id=tNdzqSQH10kJuLrRhPLbf5wtQEnaXmi1&app_version=1564667264&app_locale=en
#
# SKIP -0- downloading: /media/cola/Transfer/Download/SCscrape/Billy Talent/A Passage To Bangkok.mp3
# downloading playlist
# SKIP -1- downloading: /media/cola/Transfer/Download/SCscrape/Billy Talent/Big Red Gun.mp3
# SKIP -1- downloading: /media/cola/Transfer/Download/SCscrape/Billy Talent/Afraid of Heights.mp3
# SKIP -1- downloading: /media/cola/Transfer/Download/SCscrape/Billy Talent/Ghost Ship of Cannibal Rats.mp3
# SKIP -1- downloading: /media/cola/Transfer/Download/SCscrape/Billy Talent/Louder Than the DJ.mp3
# SKIP -1- downloading: /media/cola/Transfer/Download/SCscrape/Billy Talent/The Crutch.mp3
#
# Done 2 .. Scrolling  to https://api-v2.soundcloud.com/stream/users/1250539?offset=2007-09-27T00%3A00%3A00.000Z&limit=100&client_id=tNdzqSQH10kJuLrRhPLbf5wtQEnaXmi1&app_version=1564667264&app_locale=en
#
# downloading playlist
# SKIP -4- downloading: /media/cola/Transfer/Download/SCscrape/Billy Talent/Devil in a Midnight Mass.mp3
# SKIP -4- downloading: /media/cola/Transfer/Download/SCscrape/Billy Talent/Red Flag.mp3
# SKIP -4- downloading: /media/cola/Transfer/Download/SCscrape/Billy Talent/This Suffering.mp3
# SKIP -4- downloading: /media/cola/Transfer/Download/SCscrape/Billy Talent/Worker Bees.mp3
# SKIP -4- downloading: /media/cola/Transfer/Download/SCscrape/Billy Talent/Pins and Needles.mp3
#
# Done 5 .. Scrolling  to https://api-v2.soundcloud.com/stream/users/1250539?offset=2003-07-01T00%3A00%3A00.000Z&limit=100&client_id=tNdzqSQH10kJuLrRhPLbf5wtQEnaXmi1&app_version=1564667264&app_locale=en
#
#
# Done 5
