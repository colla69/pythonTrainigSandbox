# %%
# !git status
# Out:
# On branch master
# Your branch is ahead of 'origin/master' by 2 commits.
#   (use "git push" to publish your local commits)
#
# Changes to be committed:
#   (use "git reset HEAD <file>..." to unstage)
#
# 	new file:   .gitignore
# 	new file:   .ipynb_checkpoints/DBtest-checkpoint.ipynb
# 	new file:   .ipynb_checkpoints/TestNumpy-checkpoint.ipynb
# 	new file:   .ipynb_checkpoints/Untitled-checkpoint.ipynb
# 	new file:   DBtest.ipynb
# 	new file:   HASKELL/.ipynb_checkpoints/HaskellTestsVorlesungen-checkpoint.ipynb
# 	new file:   HASKELL/HaskellTestsVorlesungen.ipynb
# 	new file:   LInkedinJobs/.ipynb_checkpoints/Untitled-checkpoint.ipynb
# 	new file:   LInkedinJobs/Untitled.ipynb
# 	new file:   Ping_Home/.ipynb_checkpoints/Untitled-checkpoint.ipynb
# 	new file:   Ping_Home/Untitled.ipynb
# 	modified:   Ping_Home/pingHome.py
# 	new file:   Plex_Remote/.ipynb_checkpoints/Untitled-checkpoint.ipynb
# 	new file:   Plex_Remote/Untitled.ipynb
# 	new file:   TestNumpy.ipynb
# ...

# %%
# !git add .

# %%
# !git commit -m "update "
# Out:
# [master aefabc4] update
#  76 files changed, 7135 insertions(+), 150 deletions(-)
#  create mode 100644 .gitignore
#  create mode 100644 .ipynb_checkpoints/DBtest-checkpoint.ipynb
#  create mode 100644 .ipynb_checkpoints/TestNumpy-checkpoint.ipynb
#  create mode 100644 .ipynb_checkpoints/Untitled-checkpoint.ipynb
#  create mode 100644 DBtest.ipynb
#  create mode 100644 HASKELL/.ipynb_checkpoints/HaskellTestsVorlesungen-checkpoint.ipynb
#  create mode 100644 HASKELL/HaskellTestsVorlesungen.ipynb
#  create mode 100644 LInkedinJobs/.ipynb_checkpoints/Untitled-checkpoint.ipynb
#  create mode 100644 LInkedinJobs/Untitled.ipynb
#  create mode 100644 Ping_Home/.ipynb_checkpoints/Untitled-checkpoint.ipynb
#  create mode 100644 Ping_Home/Untitled.ipynb
#  create mode 100644 Plex_Remote/.ipynb_checkpoints/Untitled-checkpoint.ipynb
#  create mode 100644 Plex_Remote/Untitled.ipynb
#  create mode 100644 TestNumpy.ipynb
#  create mode 100644 Untitled.ipynb
# ...

# %%
# !git push ssh://git@github.com/colla69/pythonTrainingSandbox.git
# Out:
# Counting objects: 90, done.
# Delta compression using up to 6 threads.
# Compressing objects: 100% (84/84), done.
# Writing objects: 100% (90/90), 395.02 KiB | 3.87 MiB/s, done.
# Total 90 (delta 3), reused 0 (delta 0)
# remote: Resolving deltas: 100% (3/3), completed with 2 local objects.
# To ssh://github.com/colla69/pythonTrainingSandbox.git
#    45623bc..aefabc4  master -> master
