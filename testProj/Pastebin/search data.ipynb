# %%
import numpy
from json import dump, load
import os

path = "files/"
for dirName, subdirList, fileList in os.walk( path ):
    for f_name in fileList:
        f = open( path + f_name, "r")
        content = f.read()
        # print(content)
        if "password" in content.lower() \
            and "email" in content.lower():
            print("subl "+path+f_name)
            
        #break
# Out:
# subl files/CRdNRbJ1.txt
# subl files/gtp9F291.txt
# subl files/cQyTJZfa.txt
# subl files/V3b8jMJa.txt
# subl files/WGaa7Cfx.txt
# subl files/b4JcYPGA.txt
# subl files/rZmzj0jK.txt
# subl files/FtGwdA6F.txt
# subl files/fFkjXezZ.txt
# subl files/3xXpLkZu.txt
# subl files/JEWVKXFC.txt
# subl files/3k4c4cEx.txt
# subl files/SZ1CJfuR.txt
# subl files/kM9bdguX.txt
# subl files/AzDPALwp.txt
# subl files/AwUf2bfG.txt
# subl files/S8SDvWzC.txt
# subl files/t8FehL4F.txt
# subl files/P7xBHwHF.txt
# subl files/0XFu87at.txt
# subl files/W8xdY0TQ.txt
# subl files/ppXdLwPh.txt
# subl files/AFy1NgXz.txt
# subl files/gJu7TGde.txt
# subl files/MFTZTBCv.txt
# subl files/2gDtESKN.txt
# subl files/904q8jEc.txt
# subl files/YTb5WjXy.txt
# subl files/9GumCM95.txt
# subl files/HAz2ytXK.txt
# subl files/iHicHPEi.txt
# subl files/EyQAv3s9.txt
# subl files/GeSs19CM.txt
# subl files/GvyJa6nf.txt
# subl files/JugRUWyD.txt
# subl files/mkC1euN1.txt
# subl files/EnahBkE7.txt
# subl files/13gQY2LC.txt
# ...
