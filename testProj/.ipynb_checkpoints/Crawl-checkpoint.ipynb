# %%
print("a.mp3".split('.')[1:])

a = "a.mp3".split('.')
b = len(a)
print ( a[len(a)-1] )

ext = set()
ext.add('2')
ext.add('2')
ext.add('2')
print(ext)

# %%
import datetime
import time 

a = datetime.datetime.now()
time.sleep(10)
b = datetime.datetime.now()

print ( b-a )

# %%
from collections import defaultdict
import re
import eyed3
import json
import os
import datetime
import time 

eyed3.log.setLevel("ERROR")

class myplayer():
    def __init__(self):
        self.artists = defaultdict(list)
        self.albums = defaultdict(list)
        self.titles = defaultdict(list)
        self.rootDir = '/media/cola/Data/Music/'
        #rootDir = '/media/cola/Data/Music/New'
        for artist in data:
            for album in data[artist]:
                for song in data[artist][album]:
                    title = song[0]
                    file = song[1]
                    albums[album].append(file)
                    artists[artist].append(file)
                    titles[title].append(file)

    def load_data():
        if not os.path.isfile("data.json"): 
            files_dict, f_count, data, errors = get_data_from_dir(rootDir)            
            self.json_save(data,"data.json")
            return data = data
        else:
            return self.json_load("data.json")
            
    def json_save(self,data, fname):
        with open(fname, 'w') as fp:
            json.dump(data, fp)


    def json_load(self,fname):
        with open(fname, 'r') as fp:        
            return json.load(fp)

    def get_data_from_dir(rootdir):
        music_ext = ['MP3','m3u', 'flac', 'wma','Mp3', 'mp3']
        files_dict = defaultdict(list)
        f_count = 0
        e_count = 0
        songs = defaultdict()  
        songs['noArtist'] = {} 
        songs['noArtist']['noAlbum'] = []    

        for dirName, subdirList, fileList in os.walk(rootdir):
            for f_name in fileList:
                file_ext = f_name.split('.')[1:]
                # if music file
                if file_ext[0] in music_ext:
                    f_count += 1
                    if f_count % 25 == 0:
                        print('.', end = '')
                    if f_count % (25*100) == 0:
                        print('.\n')
                        print( datetime.datetime.now()-start )
                    file = dirName + '/' + f_name
                    audiofile = eyed3.load(path=file)
                    artist = ""
                    album = ""
                    title = ""
                    try:
                        artist = audiofile.tag.artist                    
                        album = audiofile.tag.album
                        title = audiofile.tag.title
                        song = {}
                        if title == None:
                            song["noTitle"] = file
                            songs['noArtist']['noAlbum'].append( [title,file] )
                            continue


                        if artist == None:                        
                            songs['noArtist']['noAlbum'].append([title,file])
                            continue
                        elif songs.get(artist) == None:
                            songs[artist] = {}                    
                            songs[artist]['noAlbum'] = []                   

                        if album == None:
                            if songs[artist].get('noAlbum') == None:
                                songs[artist]['noAlbum'] = []                    
                            songs[artist]['noAlbum'].append([title,file])
                        else:
                            if songs[artist].get(album) == None:
                                songs[artist][album] = []                    
                            songs[artist][album].append([title,file])

                    except AttributeError as error:
                        e_count += 1
                        continue
        return files_dict, f_count, songs, e_count


print( "starting analysis...")
start = datetime.datetime.now()
    
mp = myplayer()

    
end = datetime.datetime.now()


print("\ndone.. in %s" % str(end-start))
print('\nfilecount: %s' % f_count)
print('errorcount: %s' % errors)
# Out:
# starting analysis...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-859b64439f8c> in <module>
#     103 start = datetime.datetime.now()
#     104
# --> 105 mp = myplayer()
#     106
#     107
#
# <ipython-input-3-859b64439f8c> in __init__(self)
#      16         self.rootDir = '/media/cola/Data/Music/'
#      17         #rootDir = '/media/cola/Data/Music/New'
# ---> 18         for artist in data:
#      19             for album in data[artist]:
#      20                 for song in data[artist][album]:
#
# NameError: name 'data' is not defined
