# %%
# X - Plex - Token = y9pLd6uPWXpwbw14sRYf
# http://plex.colarietitosti.info/library/sections/2/all?X-Plex-Token=y9pLd6uPWXpwbw14sRYf
# http://plex.colarietitosti.info/library/sections?X-Plex-Token=y9pLd6uPWXpwbw14sRYf

from collections import defaultdict
from json import load, dump

from plexapi.myplex import MyPlexAccount
from plexapi.server import PlexServer


token = "y9pLd6uPWXpwbw14sRYf"
plexurl = "http://plex.colarietitosti.info:32400"
libname = "music"


class PlexBackend():
            
    def __init__(self, plexurl, token, libname):
        self.token = token
        self.plexurl = plexurl
        self.lib_name = libname
        self.plex = PlexServer(self.plexurl, self.token)
        self.music = self.plex.library.section(self.lib_name)
        #print( self.music.all())
                       
    def down_plex_lib(self):
        try:
            playlists = self.plex.playlists()
            for p in playlists:
                print( p.title )
                for track in p.items():
                    print(self.get_file(track))
                    break
                break    
                
            root = self.music.all()
            artists = defaultdict(list)
            albums = defaultdict(list)
            titles = defaultdict(list)
            count = 0
            songs = {}
            #print(root)
            for artist in root:
                artist_title = artist.title
                songs[artist_title] = {}
                print(artist_title)
                #print(artist.albums())                
                for album in artist.albums():
                    album_title = album.title
                    songs[artist_title][album_title] = []
                    print(album_title)
                    
                    for track in album.tracks():                        
                        title = track.title                        
                        file = self.get_tokenized_uri( self.get_file(track) )
                        try:
                            print("""%d 
            # %s -- %s 
            # %s
            # %s

                            """ % (count, artist_title, album_title, title))
                            songs[artist_title][album_title].append([title, file])
                            
                            count += 1      
                            
                        except Exception as ex:
                            print(ex)

                            
                        
                        #print(track.media)
                        """
                        song_uri = self.get_tokenized_uri(songmeta.get("key"))
                        try:
                            s = requests.get(song_uri).text
                            if s == "":
                                continue
                        except:
                            continue
                        song = ET.fromstring(s)
                        for p in song.iter("Part"):
                            title = songmeta.get("title")
                            file = self.get_tokenized_uri(p.get("key"))
                            songs[artist.get("title")][album.get("title")].append([title, file])
                            # print(songs)
                            # albums[album.get("title")].append(file)
                            # artists[artist.get("title")].append(file)
                            # titles[song.get("title")].append(file)
                            """
                                  
                #break
            #self.json_save(songs, self.data_path)
            print("done loading library")
        finally:
            #self.refreshing_lib = False
            return songs
    
    def json_save(self, data, fname):
        with open(fname, 'w') as fp:
            dump(data, fp)

    def json_load(self, fname):
        with open(fname, 'r') as fp:
            return load(fp)
        
    def get_tokenized_uri(self, uri):
        return plexurl+uri+"?X-Plex-Token="+token

    def get_file(self,track):
        for media in track.media:
            for p in media.parts:
                return p.key


pp = PlexBackend(plexurl,token,libname)
songs = pp.down_plex_lib()

#xml = requests.get(pp.get_tokenized_uri("/library/sections")).text
#root = ET.fromstring(xml)
#artisturi = ""
#for child in root:
#    print(child.attrib["title"])
#    if libname == child.attrib["title"].lower():
#        artisturi = pp.get_tokenized_uri("/library/sections/" + child.attrib["key"] + "/all")

#xml = requests.get(artisturi).text
#root = ET.fromstring(xml)
#artists = defaultdict(list)
#albums = defaultdict(list)
#titles = defaultdict(list)
#count = 0
#songs = {}
#for artist in root:
    #print(artist.get("title"))
    #songs[artist.get("title")] = {}
    #artist_uri = pp.get_tokenized_uri(artist.get("key"))
# Out:
# OnTheGo
# /library/parts/36060/1560257651/file.mp3
# 10 Cc
# Millenium 1970-1979;
# not enough arguments for format string
# 12 Girls Band
# Beautiful Energy
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# Eastern Energy
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# Red Hot Classics
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# Romantic Energy
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# Shanghai
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# Shining Energy
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# Twelve Girls Of Christmas
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# 1981
# The Big Heat Celbration- Tokyo 24 mai 1981
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# 1996
# Shadow, light
# not enough arguments for format string
# not enough arguments for format string
# 2011
# Turtleneck & Chain (320 kbps) (L)
# not enough arguments for format string
# 3-Way (The Golden Rule) (iTunes)
# not enough arguments for format string
# 2Pac
# Loyal To The Game
# not enough arguments for format string
# not enough arguments for format string
# Thug Nature
# not enough arguments for format string
# 2Pac
# not enough arguments for format string
# 3 Doors Down
# Away From The Sun
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# The Better Life
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# Seventeen Days
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# Time Of My Life
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# 30 Seconds To Mars
# A Beautiful Lie
# not enough arguments for format string
# Festivalbar 2007 Compilation Rossa
# not enough arguments for format string
# 4 Non Blondes
# Bigger, Better, Faster, More !;
# not enough arguments for format string
# 5cm per Second
# Byousoku 5 Centimeter Original Soundtrack
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# 883
# Uno in più
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# Hanno ucciso l'uomo ragno
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# La dura legge del gol
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# Gli anni
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# Grazie mille
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# Il grande incubo
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# L'amore e la vita al tempo degli 883
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# Nord sud ovest est
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# Single
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# Abba
# The Definitive Collection, Disc 1;
# not enough arguments for format string
# Master Series;
# not enough arguments for format string
# Gold: Greatest Hits
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# AC/DC
# Ballbreaker
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# Black Ice
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# Bonfire: Live From The Atlantic Studios [Disc 1]
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# Live In Paris [Disc 1]
# not enough arguments for format string
# Live in Paris [Disc 2]
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# Big Gun
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# Blow Up Your Video
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# Fly On The Wall
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# Flick Of The Switch
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# For Those About To Rock We Salute You
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# Back In Black
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# Back In Black
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# Highway To Hell
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# Let There Be Rock
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# Ac-Dc - Dirty Deeds Done Dirt Cheap
# not enough arguments for format string
# Dirty Deeds Done Dirt Cheap
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# High Voltage
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# High Voltage (Sp)
# not enough arguments for format string
# High Voltage
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# T.N.T.
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# T.N.T. (Australian Only)
# not enough arguments for format string
# not enough arguments for format string
# AC/DC Live: Collector's Edition [Disc 2]
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# Dirty Deeds Done Dirt Cheap
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# Dirty Deeds Done Dirt Cheap & Highway To Hell
# not enough arguments for format string
# Let There Be Rock
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# Live
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# Powerage
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# The Razor's Edge
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# Stiff Upper Lip
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# Volts
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# Who Made Who
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# Ace of Base
# Greatest Hits
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# Adriano Celentano
# I miei americani
# not enough arguments for format string
# Io non so parlar d'amore
# not enough arguments for format string
# Romantic Ballads
# not enough arguments for format string
# Super Best
# not enough arguments for format string
# not enough arguments for format string
# [Unknown Album]
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# Aerosmith
# The Essential Aerosmith
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# Pump
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# Africa Unite
# Album sconosciuto (10/06/2008 20.39.46)
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# Biografrica Unite
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# Africa United
# [Unknown Album]
# not enough arguments for format string
# Afrika Bambaataa ft. UB40
# Greatest Hits of the 80's
# not enough arguments for format string
# Afro Celt Sound System
# Volume 1: Sound Magic
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# Afro-Cuban All Stars
# A Toda Cuba Le Gusta
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# afroman
# The Good Times
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# Aftershock
# Australian Hip Hop Supports Canteen
# not enough arguments for format string
# Air Raid Anthem
# [Unknown Album]
# not enough arguments for format string
# Akon
# Konvicted
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# Akon ft. Obie Trice
# Konvicted
# not enough arguments for format string
# Al Di Meola
# Friday Night in San Francisco
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# Alain Souchon
# 20 Chansons
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# Alan Parsons Project
# I Robot
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# Star Mark Greatest Hits CD1
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# Star Mark Greatest Hits CD2
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# Alborosie
# 2 Times Revolution - Promo
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# Dub Clash
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# Escape From Babylon
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# Escape from Babylon to the Kingdom of Zion
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# Soul Pirate European Tour
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# not enough arguments for format string
# Alice
# Gioielli Rubati - Alice Canta Battiato + Bonus Tracks
